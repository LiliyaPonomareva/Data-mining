# %% [markdown]
# ### РОССИЙСКИЙ УНИВЕРСИТЕТ ДРУЖБЫ НАРОДОВ
# #### Факультет физико-математических и естественных наук
# #### Кафедра информационных технологий

# %% [markdown]
# # ОТЧЕТ ПО ЛАБОРАТОРНОЙ РАБОТЕ № 1
# # Препроцессинг данных
# ### Дисциплина: Интеллектуальный анализ данных

# %% [markdown]
# ##### Студент:  Пономарева Л. М.
# ##### Группа:   НПИбд-02-19

# %% [markdown]
# ### Москва 2022

# %% [markdown]
# ### Вариант №24
# MAGIC Gamma Telescope Data Set

# %% [markdown]
# #### Задание 1
# Используя функционал библиотеки Pandas, cчитайте заданный набор данных из репозитария UCI. Набор данных задан ссылкой на страницу набора данных и названием файла с данными, который доступен из папки с данными (data folder).

# %%
import pandas as pd

# считываем данные в объект DataFrame
my_data = pd.read_csv( "https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data", header=None)
my_data
# Out:
#              0         1       2       3       4         5         6   \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#             7        8         9  10
# 0      -8.2027  40.0920   81.8828  g
# 1      -9.9574   6.3609  205.2610  g
# ...

# %% [markdown]
# #### Задание 2
# Проведите исследование набора данных, выявляя числовые признаки. Если какие-то из числовых признаков были неправильно классифицированы, то преобразуйте их в числовые. Если в наборе для числовых признаков присутствуют пропущенные значения ('?'), то заполните их медианными значениями признаков.

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
# 0     19020 non-null float64
# 1     19020 non-null float64
# 2     19020 non-null float64
# 3     19020 non-null float64
# 4     19020 non-null float64
# 5     19020 non-null float64
# 6     19020 non-null float64
# 7     19020 non-null float64
# 8     19020 non-null float64
# 9     19020 non-null float64
# 10    19020 non-null int64
# dtypes: float64(10), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# Все признаки являются числовыми, кроме столбца, содержащего метку класса (всего 2 класса: g и h).
# В описании набора указано, что пропущенных значений нет.

# %% [markdown]
# #### Задание 3
# Определите столбец, содержащий метку класса (отклик). Если столбец, содержащий метку класса (отклик), принимает более 10 различных значений, то выполните дискретизацию этого столбца, перейдя к 4-5 диапазонам значений.

# %% [markdown]
# Преобразуем символьные метки в числовые.

# %%
my_data[10] = my_data[10].replace('g', 1)
my_data[10] = my_data[10].replace('h', 0)
my_data
# Out:
#              0         1       2       3       4         5         6   \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#             7        8         9   10
# 0      -8.2027  40.0920   81.8828   1
# 1      -9.9574   6.3609  205.2610   1
# ...

# %%
my_data[10].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #### Задание 4
# При помощи класса `SelectKBest` библиотеки scikit-learn найдите в наборе два признака, имеющих наиболее выраженную взаимосвязь с (дискретизированным) столбцом с меткой класса (откликом). Используйте для параметра `score_func` значения `chi2` или `f_classif`.

# %% [markdown]
# Оба теста работают только с неотрицательными признаками, поэтому сначала нормализуем признаки.

# %% [markdown]
# Проверим, какие признаки имеют отрицательные значения.

# %%
my_data.min()
# Out:
# 0       4.2835
# 1       0.0000
# 2       1.9413
# 3       0.0131
# 4       0.0003
# 5    -457.9161
# 6    -331.7800
# 7    -205.8947
# 8       0.0000
# 9       1.2826
# 10      0.0000
# dtype: float64

# %%
array = my_data.values
array[:,5:8]
# Out:
# array([[  27.7004,   22.011 ,   -8.2027],
#        [  26.2722,   23.8238,   -9.9574],
#        [ 116.741 ,  -64.858 ,  -45.216 ],
#        ...,
#        [  -9.3561,   41.0562,   -9.4662],
#        [   5.8043,  -93.5224,  -63.8389],
#        [-167.3125, -168.4558,   31.4755]])

# %% [markdown]
# Масштабируем данные признаков 5-7 до диапазона [0, 1] с помощью функции MinMaxScaler().

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
array[:,5:8] = min_max_scaler.fit_transform(array[:,5:8])
array[:,5:8]
# Out:
# array([[0.47003175, 0.620576  , 0.51249308],
#        [0.46864939, 0.62375579, 0.50794422],
#        [0.5562148 , 0.46820125, 0.41654048],
#        ...,
#        [0.43416449, 0.65398272, 0.5092176 ],
#        [0.44883836, 0.41792174, 0.36826282],
#        [0.28127734, 0.28648292, 0.61535411]])

# %% [markdown]
# Теперь можно перейти к отбору 2 лучших признаков.

# %%
from sklearn.feature_selection import SelectKBest,chi2,f_classif

print("\nИсходный набор данных:\n",my_data.head())

X = array[:,0:10] # входные переменные (10 признаков)
Y = array[:,10]   # выходная переменная - класс (0 или 1)

# отбор признаков
test_chi = SelectKBest(score_func=chi2, k=2)
fit_chi = test_chi.fit(X, Y)

test_f = SelectKBest(score_func=f_classif, k=2)
fit_f = test_f.fit(X, Y)

# оценки признаков
print("\nОценки признаков с помощью теста хи-квадрат:\n",fit_chi.scores_)
print("\nОценки признаков с помощью F-теста:\n",fit_f.scores_)

cols = test_chi.get_support(indices=True)
df_new_chi = my_data.iloc[:,cols]
print("\nПризнаки, отобранные тестом хи-квадрат:\n",df_new_chi.head())

cols = test_f.get_support(indices=True)
df_new_f = my_data.iloc[:,cols]
print("\nПризнаки, отобранные F-тестом:\n",df_new_f.head())
# Out:
# Исходный набор данных:
#           0         1       2       3       4         5        6        7   \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110  -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238  -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580 -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633  -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525  21.8393
#
#         8         9   10
# 0  40.0920   81.8828   1
# 1   6.3609  205.2610   1
# 2  76.9600  256.7880   1
# 3  10.4490  116.7370   1
# 4   4.6480  356.4620   1
#
# Оценки признаков с помощью теста хи-квадрат:
#  [6.06418647e+04 2.03580959e+04 2.08642257e+01 1.01257605e+00
#  2.49023713e-02 4.28678209e+00 9.48183771e+00 1.52761939e-03
#  9.96149453e+04 2.32988528e+03]
#
# Оценки признаков с помощью F-теста:
#  [1.98709656e+03 1.44337547e+03 2.67598593e+02 1.15294984e+01
# ...

# %% [markdown]
# #### Задание 5
# Для найденных признаков и (дискретизированного) столбца с меткой класса (откликом) вычислите матрицу корреляций и визуализируйте ее в виде тепловой карты (heat map).

# %% [markdown]
# Выделим отдельный датафрейм для лучших признаков и меток.

# %%
best_data = my_data.get([0,8,10])
best_data.set_axis(["Length", "M3Trans", "class"], axis='columns', inplace=True)
best_data
# Out:
#          Length  M3Trans  class
# 0       28.7967  40.0920      1
# 1       31.6036   6.3609      1
# 2      162.0520  76.9600      1
# 3       23.8172  10.4490      1
# 4       75.1362   4.6480      1
# ...         ...      ...    ...
# 19015   21.3846   2.4229      0
# 19016   28.9452  86.7975      0
# 19017   75.4455  30.2987      0
# 19018  120.5135  84.6874      0
# 19019  187.1814  52.7310      0
#
# [19020 rows x 3 columns]

# %% [markdown]
# Вычислим матрицу корреляций.

# %%
corr_matrix = best_data.corr()
corr_matrix
# Out:
#            Length   M3Trans     class
# Length   1.000000 -0.008777 -0.307572
# M3Trans -0.008777  1.000000 -0.460979
# class   -0.307572 -0.460979  1.000000

# %% [markdown]
# Сделаем визуализацию.

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(6, 5))
plt.imshow(corr_matrix, cmap='Reds')
plt.colorbar()  # добавим шкалу интенсивности цвета

plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.yticks(range(len(corr_matrix)), corr_matrix.index);

# %% [markdown]
# #### Задание 6
# Визуализируйте набор данных в виде диаграммы рассеяния на плоскости с координатами, соответствующими найденным признакам, отображая точки различных классов разными цветами. Подпишите оси и рисунок, создайте легенду набора данных.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title(r"Набор данных MAGIC Gamma Telescope", fontsize=12)
ax.set_xlabel(r"Length")        
ax.set_ylabel(r"M3Trans")

scatter = ax.scatter(best_data['Length'], best_data['M3Trans'], c=best_data['class'],
                     cmap='RdBu_r', alpha=0.2)

legend = ax.legend(*scatter.legend_elements(num=1),
                    loc="upper right", title="Class")
ax.add_artist(legend);

# %% [markdown]
# #### Задание 7
# Оставляя в наборе данных только числовые признаки, найдите и выведите на экран размерность метода главных компонент (параметр `n_components`), для которой доля объясняемой дисперсии будет не менее 97.5%.

# %%
from sklearn.decomposition import PCA 

data = my_data.drop(10, axis=1) # признаки
r = 1
variance = 0
while (variance < 97.5):
    pca = PCA( n_components = r )
    pca.fit( data )
    variance = sum(pca.explained_variance_ratio_)*100
    r+=1

print( "Размерность =",r,"\tДисперсия =",
        variance,"%" )
# Out:
# Размерность = 7 	Дисперсия = 99.21390115548277 %

# %% [markdown]
# #### Задание 8
# Пользуясь методом главных компонент (PCA), снизьте размерность набора данных до двух признаков и изобразите полученный набор данных в виде диаграммы рассеяния на плоскости, образованной двумя полученными признаками, отображая точки различных классов разными цветами. Подпишите оси и рисунок, создайте легенду набора данных.

# %%
target = my_data.get(10)

pca = PCA(n_components=2)
pca_data = pca.fit_transform(data)

plt.figure( figsize=(8, 6), dpi=100)
plt.title("PCA of MAGIC Gamma Telescope Data Set")
plt.plot(pca_data[target==1,0],
         pca_data[target==1,1],"ro", label="g") 
plt.plot(pca_data[target==0,0],
         pca_data[target==0,1],"go", alpha = 0.4, label="h")
plt.figlegend(title="Class", loc="right");
